# %% [markdown]
# *   **Año:** [2024]
# *   **Alumno/a:** [PEDRO URRETAVIZCAYA]
# *   **Legajo:** [LEGAJO]

# %% [markdown]
# # Archivos de texto plano
#
# [gutenberg.org](https://www.gutenberg.org/) (llamado así por el inventor de la imprenta moderna) es el sitio web del Proyecto Gutenberg que se dedica a la distribución y creación de eBooks. En este sitio se encuentra el [Don Quijote](https://www.gutenberg.org/ebooks/14859). El Don Quijote se puede leer en diferentes formatos, ¿no? Para la tarea, se va a usar el Don Quijote de texto plano. La siguiente celda descarga el .txt y lo guarda en el sistema para luego su futura lectura:

# %%
# !wget https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Out:
# --2024-11-22 11:58:54--  https://www.gutenberg.org/cache/epub/2000/pg2000.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2225845 (2.1M) [text/plain]
# Saving to: ‘pg2000.txt’
#
# pg2000.txt          100%[===================>]   2.12M  4.62MB/s    in 0.5s
#
# 2024-11-22 11:58:55 (4.62 MB/s) - ‘pg2000.txt’ saved [2225845/2225845]

# %%
archive = open("/content/pg2000.txt")

# %%
archive
# Out:
# <_io.TextIOWrapper name='/content/pg2000.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Para estas consignas, no se puede usar modulos externos a Python***

# %% [markdown]
# Del archivo descargado, calcular la cantidad de lineas:

# %%
with open("/content/pg2000.txt", 'r') as file:
    num_lineas = len(file.readlines())

print(f"El archivo tiene {num_lineas} líneas.")
# Out:
# El archivo tiene 38055 líneas.

# %% [markdown]
# Del archivo descargado, calcular la cantidad de veces que se dice:
# *   'Quijote'
# *   'mancha'
# *   'españa'
#
# Considerar que, por ejemplo, 'QuiJoTe' es lo mismo que 'quijote' (no *case sensitive*).

# %%
quijote = 0
mancha = 0
españa = 0


with open("/content/pg2000.txt", 'r') as file:
    lib = file.read().lower()
    quijote = lib.count('quijote')
    mancha = lib.count('mancha')
    españa = lib.count('españa')

print(f"La palabra 'quijote' aparece {quijote} veces.")
print(f"La palabra 'mancha' aparece {mancha} veces.")
print(f"La palabra 'españa' aparece {españa} veces.")
# Out:
# La palabra 'quijote' aparece 2249 veces.
# La palabra 'mancha' aparece 196 veces.
# La palabra 'españa' aparece 78 veces.

# %% [markdown]
# ¿Quien es el autor y titulo del libro? Responderlo usando las herramientas utilizadas en la celda anterior (Tip: abrir el archivo de texto y ver como son las primeras lineas).

# %%
titulo = ""
autor = ""

with open("/content/pg2000.txt", 'r', encoding='utf-8') as file:
    for linea in file:
        if "Title:" in linea:
            titulo = linea.replace("Title:", "").strip()
        elif "Author:" in linea:
            autor = linea.replace("Author:", "").strip()
        if titulo and autor:
            break

print(f"Título: {titulo}")
print(f"Autor: {autor}")
# Out:
# Título: Don Quijote
# Autor: Miguel de Cervantes Saavedra

# %% [markdown]
# # Archivos .csv
#
# *Robert* De Niro actuó en mas de 100 peliculas y Rotten Tomatoes es un sitio web en el que se pueden leer criticas y ratings a peliculas hechos por críticos y usuarios. La siguiente linea descarga un archivo .csv en el que tenemos peliculas de De Niro junto a su rating en Rotten Tomatoes:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Out:
# --2024-11-22 11:58:56--  https://people.sc.fsu.edu/~jburkardt/data/csv/deniro.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2391 (2.3K) [text/csv]
# Saving to: ‘deniro.csv’
#
# deniro.csv          100%[===================>]   2.33K  --.-KB/s    in 0s
#
# 2024-11-22 11:58:56 (1.24 GB/s) - ‘deniro.csv’ saved [2391/2391]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ***NOTA: Apartir de aca, se pueden usar modulos externos de Python***

# %% [markdown]
# Sabemos que el archivo tiene en su primera linea los 'headers'. ¿Cuales son? Imprimirlos.

# %%
import pandas as pd
data = pd.read_csv('deniro.csv',quotechar='"',skipinitialspace=True)
headers = data.columns.tolist()
print(headers)
# Out:
# ['Year', 'Score', 'Title']

# %% [markdown]
# Convertir la información del archivo .csv a un diccionario.

# %%
data_dict = data.to_dict()
print(data_dict)
# Out:
# {'Year': {0: 1968, 1: 1970, 2: 1970, 3: 1971, 4: 1973, 5: 1973, 6: 1974, 7: 1976, 8: 1976, 9: 1977, 10: 1977, 11: 1978, 12: 1980, 13: 1981, 14: 1983, 15: 1984, 16: 1984, 17: 1985, 18: 1986, 19: 1987, 20: 1987, 21: 1987, 22: 1988, 23: 1989, 24: 1989, 25: 1990, 26: 1990, 27: 1990, 28: 1991, 29: 1991, 30: 1991, 31: 1991, 32: 1992, 33: 1992, 34: 1993, 35: 1993, 36: 1993, 37: 1994, 38: 1995, 39: 1995, 40: 1996, 41: 1996, 42: 1996, 43: 1997, 44: 1997, 45: 1997, 46: 1998, 47: 1998, 48: 1999, 49: 1999, 50: 2000, 51: 2000, 52: 2000, 53: 2001, 54: 2001, 55: 2002, 56: 2002, 57: 2003, 58: 2004, 59: 2004, 60: 2005, 61: 2005, 62: 2005, 63: 2006, 64: 2007, 65: 2007, 66: 2008, 67: 2008, 68: 2009, 69: 2010, 70: 2010, 71: 2010, 72: 2011, 73: 2011, 74: 2011, 75: 2012, 76: 2012, 77: 2012, 78: 2013, 79: 2013, 80: 2013, 81: 2013, 82: 2014, 83: 2015, 84: 2015, 85: 2015, 86: 2016}, 'Score': {0: 86, 1: 17, 2: 73, 3: 40, 4: 98, 5: 88, 6: 97, 7: 41, 8: 99, 9: 47, 10: 67, 11: 93, 12: 97, 13: 75, 14: 90, 15: 89, 16: 60, 17: 98, 18: 65, 19: 100, 20: 80, 21: 78, 22: 96, 23: 64, 24: 47, 25: 88, 26: 29, 27: 96, 28: 76, 29: 69, 30: 65, 31: 71, 32: 87, 33: 67, 34: 75, 35: 78, 36: 96, 37: 39, 38: 80, 39: 86, 40: 74, 41: 38, 42: 80, 43: 85, 44: 87, 45: 72, 46: 68, 47: 38, 48: 69, 49: 43, 50: 43, 51: 84, 52: 41, 53: 73, 54: 33, 55: 48, 56: 27, 57: 4, 58: 35, 59: 38, 60: 4, 61: 46, 62: 13, 63: 54, 64: 21, 65: 76, 66: 19, 67: 51, 68: 46, 69: 72, 70: 10, 71: 50, 72: 25, 73: 7, 74: 70, 75: 92, 76: 51, 77: 29, 78: 46, 79: 7, 80: 29, 81: 11, 82: 9, 83: 60, 84: 26, 85: 61, 86: 11}, 'Title': {0: 'Greetings', 1: 'Bloody Mama', 2: 'Hi, Mom!', 3: 'Born to Win', 4: 'Mean Streets', 5: 'Bang the Drum Slowly', 6: 'The Godfather, Part II', 7: 'The Last Tycoon', 8: 'Taxi Driver', 9: '1900', 10: 'New York, New York', 11: 'The Deer Hunter', 12: 'Raging Bull', 13: 'True Confessions', 14: 'The King of Comedy', 15: 'Once Upon a Time in America', 16: 'Falling in Love', 17: 'Brazil', 18: 'The Mission', 19: 'Dear America: Letters Home From Vietnam', 20: 'The Untouchables', 21: 'Angel Heart', 22: 'Midnight Run', 23: 'Jacknife', 24: "We're No Angels", 25: 'Awakenings', 26: 'Stanley & Iris', 27: 'Goodfellas', 28: 'Cape Fear', 29: 'Mistress', 30: 'Guilty by Suspicion', 31: 'Backdraft', 32: 'Thunderheart', 33: 'Night and the City', 34: "This Boy's Life", 35: 'Mad Dog and Glory', 36: 'A Bronx Tale', 37: "Mary Shelley's Frankenstein", 38: 'Casino', 39: 'Heat', 40: 'Sleepers', 41: 'The Fan', 42: "Marvin's Room", 43: 'Wag the Dog', 44: 'Jackie Brown', 45: 'Cop Land', 46: 'Ronin', 47: 'Great Expectations', 48: 'Analyze This', 49: 'Flawless', 50: 'The Adventures of Rocky & Bullwinkle', 51: 'Meet the Parents', 52: 'Men of Honor', 53: 'The Score', 54: '15 Minutes', 55: 'City by the Sea', 56: 'Analyze That', 57: 'Godsend', 58: 'Shark Tale', 59: 'Meet the Fockers', 60: 'The Bridge of San Luis Rey', 61: 'Rent', 62: 'Hide and Seek', 63: 'The Good Shepherd', 64: 'Arthur and the Invisibles', 65: 'Captain Shakespeare', 66: 'Righteous Kill', 67: 'What Just Happened?', 68: "Everybody's Fine", 69: 'Machete', 70: 'Little Fockers', 71: 'Stone', 72: 'Killer Elite', 73: "New Year's Eve", 74: 'Limitless', 75: 'Silver Linings Playbook', 76: 'Being Flynn', 77: 'Red Lights', 78: 'Last Vegas', 79: 'The Big Wedding', 80: 'Grudge Match', 81: 'Killing Season', 82: 'The Bag Man', 83: 'Joy', 84: 'Heist', 85: 'The Intern', 86: 'Dirty Grandpa'}}

# %% [markdown]
# ¿Cuantas peliculas hay registradas en el archivo .csv?

# %%
num_peliculas = len(data)
num_peliculas
# Out:
# 87

# %% [markdown]
# Imprimir las peliculas mejor y peor rankeadas del archivo (imprimir sus respectivos rankings)

# %%
data_ord = data.sort_values(by='Score', ascending=False)
mejor_pelicula = data_ord.iloc[0]
peor_pelicula = data_ord.iloc[-1]
print(f"Mejor película: {mejor_pelicula['Title']} con un ranking de {mejor_pelicula['Score']}")
print(f"Peor película: {peor_pelicula['Title']} con un ranking de {peor_pelicula['Score']}")
# Out:
# Mejor película: Dear America: Letters Home From Vietnam con un ranking de 100
# Peor película: The Bridge of San Luis Rey con un ranking de 4

# %% [markdown]
# # Base de datos - Relacionales
#
# SQLite es una biblioteca de C que provee una base de datos ligera basada en disco que no requiere un proceso de servidor separado y permite acceder a la base de datos usando una variación no estándar del lenguaje de consulta SQL. Algunas aplicaciones pueden usar SQLite para almacenamiento interno. También es posible prototipar una aplicación usando SQLite y luego transferir el código a una base de datos más grande como PostgreSQL u Oracle.

# %% [markdown]
# Realizamos el `import` e indicamos el archivo en el que vamos a guardar la base de datos:

# %%
import sqlite3
conn = sqlite3.connect('db.db')

# %% [markdown]
# La siguiente linea de codigo agrega filas a la misma. Por favor, ejecutar la siguiente celda para la consigna:

# %%
# !wget https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv

cur = conn.cursor()
cur.execute("CREATE TABLE t (GameNumber, GameLength);")

with open('snakes_count_10000.csv','r') as csv_file:
  lines = csv_file.readlines()[1:]
  lines = [l.split(',') for l in lines]
  to_db = [(l[0].strip(), l[1].strip()) for l in lines]

cur.executemany("INSERT INTO t (GameNumber, GameLength) VALUES (?, ?);", to_db)
conn.commit()
conn.close()
# Out:
# --2024-11-22 11:58:57--  https://people.sc.fsu.edu/~jburkardt/data/csv/snakes_count_10000.csv
# Resolving people.sc.fsu.edu (people.sc.fsu.edu)... 144.174.0.22
# Connecting to people.sc.fsu.edu (people.sc.fsu.edu)|144.174.0.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89011 (87K) [text/csv]
# Saving to: ‘snakes_count_10000.csv’
#
# snakes_count_10000. 100%[===================>]  86.92K   411KB/s    in 0.2s
#
# 2024-11-22 11:58:58 (411 KB/s) - ‘snakes_count_10000.csv’ saved [89011/89011]

# %% [markdown]
# ## Consignas

# %% [markdown]
# ¿Como luce la base de datos? Imprimirla.

# %%
to_db
# Out:
# [('1', '30'),
#  ('2', '29'),
#  ('3', '31'),
#  ('4', '16'),
#  ('5', '24'),
#  ('6', '29'),
#  ('7', '28'),
#  ('8', '117'),
#  ('9', '42'),
#  ('10', '23'),
#  ('11', '40'),
#  ('12', '15'),
#  ('13', '18'),
#  ('14', '51'),
#  ('15', '15'),
#  ('16', '19'),
#  ('17', '30'),
#  ('18', '25'),
#  ('19', '17'),
#  ('20', '55'),
#  ('21', '20'),
#  ('22', '12'),
#  ('23', '39'),
#  ('24', '25'),
#  ('25', '56'),
#  ('26', '61'),
#  ('27', '77'),
#  ('28', '34'),
#  ('29', '14'),
#  ('30', '8'),
#  ('31', '31'),
#  ('32', '34'),
#  ('33', '22'),
#  ('34', '12'),
#  ('35', '52'),
#  ('36', '50'),
#  ('37', '24'),
#  ('38', '20'),
#  ('39', '91'),
#  ('40', '33'),
#  ('41', '27'),
#  ('42', '25'),
#  ('43', '83'),
#  ('44', '12'),
#  ('45', '21'),
#  ('46', '38'),
#  ('47', '20'),
#  ('48', '24'),
#  ('49', '37'),
#  ('50', '18'),
#  ('51', '56'),
#  ('52', '20'),
#  ('53', '47'),
#  ('54', '51'),
#  ('55', '22'),
#  ('56', '46'),
#  ('57', '24'),
#  ('58', '35'),
#  ('59', '28'),
#  ('60', '12'),
#  ('61', '28'),
#  ('62', '43'),
#  ('63', '50'),
#  ('64', '37'),
#  ('65', '127'),
#  ('66', '11'),
#  ('67', '12'),
#  ('68', '22'),
#  ('69', '25'),
#  ('70', '57'),
#  ('71', '53'),
#  ('72', '38'),
#  ('73', '33'),
#  ('74', '16'),
#  ('75', '35'),
#  ('76', '29'),
#  ('77', '23'),
#  ('78', '21'),
#  ('79', '11'),
#  ('80', '31'),
#  ('81', '12'),
#  ('82', '37'),
#  ('83', '40'),
#  ('84', '29'),
#  ('85', '14'),
#  ('86', '15'),
#  ('87', '38'),
#  ('88', '74'),
#  ('89', '19'),
#  ('90', '121'),
#  ('91', '52'),
#  ('92', '25'),
#  ('93', '14'),
#  ('94', '12'),
#  ('95', '31'),
#  ('96', '25'),
#  ('97', '16'),
#  ('98', '19'),
#  ('99', '54'),
#  ('100', '24'),
#  ('101', '62'),
#  ('102', '27'),
#  ('103', '21'),
#  ('104', '30'),
#  ('105', '63'),
#  ('106', '14'),
#  ('107', '27'),
#  ('108', '46'),
#  ('109', '8'),
#  ('110', '19'),
#  ('111', '81'),
#  ('112', '136'),
#  ('113', '60'),
#  ('114', '44'),
#  ('115', '44'),
#  ('116', '115'),
#  ('117', '28'),
#  ('118', '15'),
#  ('119', '26'),
#  ('120', '31'),
#  ('121', '46'),
#  ('122', '29'),
#  ('123', '22'),
#  ('124', '25'),
#  ('125', '37'),
#  ('126', '78'),
#  ('127', '11'),
#  ('128', '17'),
#  ('129', '20'),
#  ('130', '38'),
#  ('131', '30'),
#  ('132', '51'),
#  ('133', '42'),
#  ('134', '64'),
#  ('135', '37'),
#  ('136', '32'),
#  ('137', '32'),
#  ('138', '35'),
#  ('139', '34'),
#  ('140', '36'),
#  ('141', '55'),
#  ('142', '35'),
#  ('143', '13'),
#  ('144', '109'),
#  ('145', '39'),
#  ('146', '39'),
#  ('147', '69'),
#  ('148', '28'),
#  ('149', '13'),
#  ('150', '16'),
#  ('151', '23'),
#  ('152', '14'),
#  ('153', '116'),
#  ('154', '36'),
#  ('155', '41'),
#  ('156', '40'),
#  ('157', '31'),
#  ('158', '39'),
#  ('159', '21'),
#  ('160', '34'),
#  ('161', '11'),
#  ('162', '46'),
#  ('163', '27'),
#  ('164', '10'),
#  ('165', '47'),
#  ('166', '12'),
#  ('167', '42'),
#  ('168', '34'),
#  ('169', '16'),
#  ('170', '19'),
#  ('171', '100'),
#  ('172', '34'),
#  ('173', '20'),
#  ('174', '23'),
#  ('175', '29'),
#  ('176', '32'),
#  ('177', '81'),
#  ('178', '15'),
#  ('179', '50'),
#  ('180', '67'),
#  ('181', '76'),
#  ('182', '30'),
#  ('183', '16'),
#  ('184', '20'),
#  ('185', '37'),
#  ('186', '23'),
#  ('187', '18'),
#  ('188', '47'),
#  ('189', '13'),
#  ('190', '24'),
#  ('191', '8'),
#  ('192', '16'),
#  ('193', '24'),
#  ('194', '26'),
#  ('195', '35'),
#  ('196', '14'),
#  ('197', '11'),
#  ('198', '43'),
#  ('199', '48'),
#  ('200', '19'),
#  ('201', '40'),
#  ('202', '197'),
#  ('203', '33'),
#  ('204', '41'),
#  ('205', '28'),
#  ('206', '25'),
#  ('207', '17'),
#  ('208', '62'),
#  ('209', '17'),
#  ('210', '71'),
#  ('211', '30'),
#  ('212', '41'),
#  ('213', '17'),
#  ('214', '51'),
#  ('215', '9'),
#  ('216', '33'),
#  ('217', '47'),
#  ('218', '13'),
#  ('219', '59'),
#  ('220', '17'),
#  ('221', '9'),
#  ('222', '51'),
#  ('223', '26'),
#  ('224', '39'),
#  ('225', '39'),
#  ('226', '35'),
#  ('227', '18'),
#  ('228', '45'),
#  ('229', '36'),
#  ('230', '34'),
#  ('231', '30'),
#  ('232', '34'),
#  ('233', '36'),
#  ('234', '14'),
#  ('235', '7'),
#  ('236', '28'),
#  ('237', '34'),
#  ('238', '49'),
#  ('239', '95'),
#  ('240', '66'),
#  ('241', '36'),
#  ('242', '32'),
#  ('243', '25'),
#  ('244', '25'),
#  ('245', '30'),
#  ('246', '15'),
#  ('247', '12'),
#  ('248', '40'),
#  ('249', '32'),
#  ('250', '26'),
#  ('251', '18'),
#  ('252', '60'),
#  ('253', '21'),
#  ('254', '79'),
#  ('255', '17'),
#  ('256', '42'),
#  ('257', '40'),
#  ('258', '23'),
#  ('259', '39'),
#  ('260', '58'),
#  ('261', '19'),
#  ('262', '45'),
#  ('263', '17'),
#  ('264', '66'),
#  ('265', '31'),
#  ('266', '25'),
#  ('267', '38'),
#  ('268', '16'),
#  ('269', '36'),
#  ('270', '20'),
#  ('271', '29'),
#  ('272', '26'),
#  ('273', '32'),
#  ('274', '22'),
#  ('275', '11'),
#  ('276', '60'),
#  ('277', '133'),
#  ('278', '46'),
#  ('279', '13'),
#  ('280', '20'),
#  ('281', '34'),
#  ('282', '20'),
#  ('283', '79'),
#  ('284', '44'),
#  ('285', '9'),
#  ('286', '63'),
#  ('287', '65'),
#  ('288', '43'),
#  ('289', '19'),
#  ('290', '68'),
#  ('291', '20'),
#  ('292', '24'),
#  ('293', '12'),
#  ('294', '83'),
#  ('295', '20'),
#  ('296', '33'),
#  ('297', '15'),
#  ('298', '29'),
#  ('299', '19'),
#  ('300', '63'),
#  ('301', '31'),
#  ('302', '47'),
#  ('303', '20'),
#  ('304', '45'),
#  ('305', '10'),
#  ('306', '13'),
#  ('307', '10'),
#  ('308', '23'),
#  ('309', '8'),
#  ('310', '84'),
#  ('311', '38'),
#  ('312', '22'),
#  ('313', '43'),
#  ('314', '25'),
#  ('315', '32'),
#  ('316', '29'),
#  ('317', '20'),
#  ('318', '26'),
#  ('319', '26'),
#  ('320', '40'),
#  ('321', '129'),
#  ('322', '45'),
#  ('323', '23'),
#  ('324', '67'),
#  ('325', '49'),
#  ('326', '90'),
#  ('327', '17'),
#  ('328', '76'),
#  ('329', '27'),
#  ('330', '136'),
#  ('331', '33'),
#  ('332', '21'),
#  ('333', '18'),
#  ('334', '14'),
#  ('335', '24'),
#  ('336', '14'),
#  ('337', '30'),
#  ('338', '26'),
#  ('339', '26'),
#  ('340', '29'),
#  ('341', '18'),
#  ('342', '53'),
#  ('343', '47'),
#  ('344', '93'),
#  ('345', '47'),
#  ('346', '9'),
#  ('347', '56'),
#  ('348', '60'),
#  ('349', '12'),
#  ('350', '69'),
#  ('351', '18'),
#  ('352', '38'),
#  ('353', '38'),
#  ('354', '27'),
#  ('355', '42'),
#  ('356', '61'),
#  ('357', '33'),
#  ('358', '39'),
#  ('359', '47'),
#  ('360', '13'),
#  ('361', '27'),
#  ('362', '17'),
#  ('363', '99'),
#  ('364', '44'),
#  ('365', '42'),
#  ('366', '43'),
#  ('367', '24'),
#  ('368', '29'),
#  ('369', '48'),
#  ('370', '34'),
#  ('371', '43'),
#  ('372', '52'),
#  ('373', '10'),
#  ('374', '28'),
#  ('375', '41'),
#  ('376', '87'),
#  ('377', '9'),
#  ('378', '22'),
#  ('379', '60'),
#  ('380', '19'),
#  ('381', '33'),
#  ('382', '35'),
#  ('383', '26'),
#  ('384', '22'),
#  ('385', '24'),
#  ('386', '68'),
#  ('387', '23'),
#  ('388', '19'),
#  ('389', '32'),
#  ('390', '32'),
#  ('391', '23'),
#  ('392', '22'),
#  ('393', '23'),
#  ('394', '49'),
#  ('395', '20'),
#  ('396', '11'),
#  ('397', '64'),
#  ('398', '24'),
#  ('399', '29'),
#  ('400', '47'),
#  ('401', '20'),
#  ('402', '13'),
#  ('403', '15'),
#  ('404', '34'),
#  ('405', '89'),
#  ('406', '81'),
#  ('407', '22'),
#  ('408', '79'),
#  ('409', '37'),
#  ('410', '18'),
#  ('411', '26'),
#  ('412', '35'),
#  ('413', '26'),
#  ('414', '13'),
#  ('415', '25'),
#  ('416', '118'),
#  ('417', '13'),
#  ('418', '23'),
#  ('419', '14'),
#  ('420', '12'),
#  ('421', '17'),
#  ('422', '16'),
#  ('423', '35'),
#  ('424', '19'),
#  ('425', '114'),
#  ('426', '97'),
#  ('427', '24'),
#  ('428', '71'),
#  ('429', '17'),
#  ('430', '22'),
#  ('431', '25'),
#  ('432', '36'),
#  ('433', '53'),
#  ('434', '51'),
#  ('435', '14'),
#  ('436', '48'),
#  ('437', '45'),
#  ('438', '25'),
#  ('439', '18'),
#  ('440', '17'),
#  ('441', '16'),
#  ('442', '83'),
#  ('443', '22'),
#  ('444', '16'),
#  ('445', '47'),
#  ('446', '25'),
#  ('447', '48'),
#  ('448', '15'),
#  ('449', '57'),
#  ('450', '14'),
#  ('451', '24'),
#  ('452', '38'),
#  ('453', '100'),
#  ('454', '34'),
#  ('455', '37'),
#  ('456', '59'),
#  ('457', '24'),
#  ('458', '16'),
#  ('459', '55'),
#  ('460', '36'),
#  ('461', '28'),
#  ('462', '33'),
#  ('463', '65'),
#  ('464', '12'),
#  ('465', '14'),
#  ('466', '32'),
#  ('467', '15'),
#  ('468', '28'),
#  ('469', '21'),
#  ('470', '84'),
#  ('471', '46'),
#  ('472', '35'),
#  ('473', '31'),
#  ('474', '16'),
#  ('475', '26'),
#  ('476', '16'),
#  ('477', '14'),
#  ('478', '29'),
#  ('479', '9'),
#  ('480', '29'),
#  ('481', '35'),
#  ('482', '47'),
#  ('483', '30'),
#  ('484', '13'),
#  ('485', '23'),
#  ('486', '16'),
#  ('487', '30'),
#  ('488', '23'),
#  ('489', '27'),
#  ('490', '13'),
#  ('491', '37'),
#  ('492', '26'),
#  ('493', '17'),
#  ('494', '56'),
#  ('495', '73'),
#  ('496', '144'),
#  ('497', '40'),
#  ('498', '21'),
#  ('499', '47'),
#  ('500', '39'),
#  ('501', '16'),
#  ('502', '37'),
#  ('503', '12'),
#  ('504', '17'),
#  ('505', '13'),
#  ('506', '12'),
#  ('507', '48'),
#  ('508', '73'),
#  ('509', '41'),
#  ('510', '50'),
#  ('511', '10'),
#  ('512', '65'),
#  ('513', '58'),
#  ('514', '13'),
#  ('515', '18'),
#  ('516', '22'),
#  ('517', '10'),
#  ('518', '11'),
#  ('519', '31'),
#  ('520', '27'),
#  ('521', '77'),
#  ('522', '21'),
#  ('523', '30'),
#  ('524', '16'),
#  ('525', '15'),
#  ('526', '18'),
#  ('527', '47'),
#  ('528', '56'),
#  ('529', '95'),
#  ('530', '33'),
#  ('531', '42'),
#  ('532', '51'),
#  ('533', '13'),
#  ('534', '29'),
#  ('535', '53'),
#  ('536', '41'),
#  ('537', '30'),
#  ('538', '16'),
#  ('539', '24'),
#  ('540', '16'),
#  ('541', '70'),
#  ('542', '28'),
#  ('543', '24'),
#  ('544', '45'),
#  ('545', '47'),
#  ('546', '64'),
#  ('547', '8'),
#  ('548', '23'),
#  ('549', '16'),
#  ('550', '54'),
#  ('551', '11'),
#  ('552', '92'),
#  ('553', '11'),
#  ('554', '64'),
#  ('555', '11'),
#  ('556', '58'),
#  ('557', '35'),
#  ('558', '19'),
#  ('559', '30'),
#  ('560', '23'),
#  ('561', '157'),
#  ('562', '40'),
#  ('563', '19'),
#  ('564', '15'),
#  ('565', '39'),
#  ('566', '77'),
#  ('567', '30'),
#  ('568', '13'),
#  ('569', '11'),
#  ('570', '18'),
#  ('571', '42'),
#  ('572', '27'),
#  ('573', '16'),
#  ('574', '35'),
#  ('575', '37'),
#  ('576', '72'),
#  ('577', '31'),
#  ('578', '20'),
#  ('579', '36'),
#  ('580', '40'),
#  ('581', '23'),
#  ('582', '7'),
#  ('583', '20'),
#  ('584', '46'),
#  ('585', '103'),
#  ('586', '90'),
#  ('587', '15'),
#  ('588', '63'),
#  ('589', '86'),
#  ('590', '18'),
#  ('591', '13'),
#  ('592', '20'),
#  ('593', '15'),
#  ('594', '8'),
#  ('595', '39'),
#  ('596', '54'),
#  ('597', '52'),
#  ('598', '36'),
#  ('599', '9'),
#  ('600', '41'),
#  ('601', '14'),
#  ('602', '66'),
#  ('603', '34'),
#  ('604', '13'),
#  ('605', '19'),
#  ('606', '12'),
#  ('607', '35'),
#  ('608', '37'),
#  ('609', '46'),
#  ('610', '25'),
#  ('611', '53'),
#  ('612', '30'),
#  ('613', '27'),
#  ('614', '30'),
#  ('615', '28'),
#  ('616', '91'),
#  ('617', '18'),
#  ('618', '19'),
#  ('619', '32'),
#  ('620', '24'),
#  ('621', '52'),
#  ('622', '18'),
#  ('623', '88'),
#  ('624', '38'),
#  ('625', '25'),
#  ('626', '20'),
#  ('627', '51'),
#  ('628', '25'),
#  ('629', '44'),
#  ('630', '14'),
#  ('631', '17'),
#  ('632', '54'),
#  ('633', '35'),
#  ('634', '40'),
#  ('635', '59'),
#  ('636', '34'),
#  ('637', '30'),
#  ('638', '30'),
#  ('639', '33'),
#  ('640', '60'),
#  ('641', '46'),
#  ('642', '26'),
#  ('643', '61'),
#  ('644', '45'),
#  ('645', '35'),
#  ('646', '33'),
#  ('647', '18'),
#  ('648', '31'),
#  ('649', '44'),
#  ('650', '24'),
#  ('651', '12'),
#  ('652', '15'),
#  ('653', '60'),
#  ('654', '24'),
#  ('655', '13'),
#  ('656', '40'),
#  ('657', '44'),
#  ('658', '17'),
#  ('659', '14'),
#  ('660', '19'),
#  ('661', '16'),
#  ('662', '40'),
#  ('663', '96'),
#  ('664', '23'),
#  ('665', '35'),
#  ('666', '33'),
#  ('667', '45'),
#  ('668', '18'),
#  ('669', '33'),
#  ('670', '15'),
#  ('671', '43'),
#  ('672', '19'),
#  ('673', '36'),
#  ('674', '28'),
#  ('675', '32'),
#  ('676', '9'),
#  ('677', '34'),
#  ('678', '8'),
#  ('679', '21'),
#  ('680', '26'),
#  ('681', '13'),
#  ('682', '34'),
#  ('683', '15'),
#  ('684', '32'),
#  ('685', '30'),
#  ('686', '21'),
#  ('687', '28'),
#  ('688', '28'),
#  ('689', '37'),
#  ('690', '10'),
#  ('691', '28'),
#  ('692', '38'),
#  ('693', '18'),
#  ('694', '23'),
#  ('695', '46'),
#  ('696', '30'),
#  ('697', '31'),
#  ('698', '34'),
#  ('699', '26'),
#  ('700', '13'),
#  ('701', '36'),
#  ('702', '11'),
#  ('703', '48'),
#  ('704', '24'),
#  ('705', '48'),
#  ('706', '18'),
#  ('707', '152'),
#  ('708', '13'),
#  ('709', '106'),
#  ('710', '19'),
#  ('711', '12'),
#  ('712', '20'),
#  ('713', '12'),
#  ('714', '39'),
#  ('715', '20'),
#  ('716', '20'),
#  ('717', '52'),
#  ('718', '77'),
#  ('719', '37'),
#  ('720', '79'),
#  ('721', '14'),
#  ('722', '23'),
#  ('723', '32'),
#  ('724', '56'),
#  ('725', '83'),
#  ('726', '47'),
#  ('727', '17'),
#  ('728', '12'),
#  ('729', '22'),
#  ('730', '27'),
#  ('731', '47'),
#  ('732', '25'),
#  ('733', '33'),
#  ('734', '30'),
#  ('735', '19'),
#  ('736', '36'),
#  ('737', '75'),
#  ('738', '20'),
#  ('739', '57'),
#  ('740', '12'),
#  ('741', '76'),
#  ('742', '30'),
#  ('743', '35'),
#  ('744', '77'),
#  ('745', '10'),
#  ('746', '73'),
#  ('747', '13'),
#  ('748', '39'),
#  ('749', '34'),
#  ('750', '31'),
#  ('751', '13'),
#  ('752', '14'),
#  ('753', '10'),
#  ('754', '45'),
#  ('755', '55'),
#  ('756', '29'),
#  ('757', '25'),
#  ('758', '47'),
#  ('759', '95'),
#  ('760', '13'),
#  ('761', '54'),
#  ('762', '17'),
#  ('763', '35'),
#  ('764', '74'),
#  ('765', '60'),
#  ('766', '14'),
#  ('767', '50'),
#  ('768', '30'),
#  ('769', '55'),
#  ('770', '22'),
#  ('771', '43'),
#  ('772', '92'),
#  ('773', '35'),
#  ('774', '47'),
#  ('775', '12'),
#  ('776', '51'),
#  ('777', '12'),
#  ('778', '93'),
#  ('779', '41'),
#  ('780', '47'),
#  ('781', '69'),
#  ('782', '36'),
#  ('783', '38'),
#  ('784', '32'),
#  ('785', '52'),
#  ('786', '13'),
#  ('787', '20'),
#  ('788', '48'),
#  ('789', '52'),
#  ('790', '33'),
#  ('791', '39'),
#  ('792', '56'),
#  ('793', '20'),
#  ('794', '41'),
#  ('795', '16'),
#  ('796', '70'),
#  ('797', '57'),
#  ('798', '85'),
#  ('799', '23'),
#  ('800', '17'),
#  ('801', '30'),
#  ('802', '33'),
#  ('803', '11'),
#  ('804', '26'),
#  ('805', '50'),
#  ('806', '40'),
#  ('807', '20'),
#  ('808', '68'),
#  ('809', '12'),
#  ('810', '75'),
#  ('811', '14'),
#  ('812', '36'),
#  ('813', '35'),
#  ('814', '39'),
#  ('815', '30'),
#  ('816', '13'),
#  ('817', '62'),
#  ('818', '23'),
#  ('819', '26'),
#  ('820', '56'),
#  ('821', '30'),
#  ('822', '40'),
#  ('823', '12'),
#  ('824', '23'),
#  ('825', '30'),
#  ('826', '17'),
#  ('827', '19'),
#  ('828', '17'),
#  ('829', '19'),
#  ('830', '45'),
#  ('831', '14'),
#  ('832', '60'),
#  ('833', '49'),
#  ('834', '32'),
#  ('835', '12'),
#  ('836', '44'),
#  ('837', '43'),
#  ('838', '21'),
#  ('839', '9'),
#  ('840', '12'),
#  ('841', '16'),
#  ('842', '14'),
#  ('843', '17'),
#  ('844', '18'),
#  ('845', '29'),
#  ('846', '56'),
#  ('847', '34'),
#  ('848', '24'),
#  ('849', '58'),
#  ('850', '27'),
#  ('851', '12'),
#  ('852', '23'),
#  ('853', '75'),
#  ('854', '15'),
#  ('855', '20'),
#  ('856', '31'),
#  ('857', '51'),
#  ('858', '10'),
#  ('859', '70'),
#  ('860', '70'),
#  ('861', '71'),
#  ('862', '53'),
#  ('863', '35'),
#  ('864', '12'),
#  ('865', '23'),
#  ('866', '26'),
#  ('867', '25'),
#  ('868', '48'),
#  ('869', '45'),
#  ('870', '36'),
#  ('871', '38'),
#  ('872', '27'),
#  ('873', '29'),
#  ('874', '55'),
#  ('875', '34'),
#  ('876', '38'),
#  ('877', '17'),
#  ('878', '43'),
#  ('879', '32'),
#  ('880', '40'),
#  ('881', '27'),
#  ('882', '8'),
#  ('883', '24'),
#  ('884', '18'),
#  ('885', '29'),
#  ('886', '11'),
#  ('887', '23'),
#  ('888', '30'),
#  ('889', '64'),
#  ('890', '65'),
#  ('891', '19'),
#  ('892', '52'),
#  ('893', '8'),
#  ('894', '29'),
#  ('895', '48'),
#  ('896', '67'),
#  ('897', '18'),
#  ('898', '18'),
#  ('899', '11'),
#  ('900', '53'),
#  ('901', '87'),
#  ('902', '24'),
#  ('903', '25'),
#  ('904', '27'),
#  ('905', '14'),
#  ('906', '80'),
#  ('907', '17'),
#  ('908', '32'),
#  ('909', '16'),
#  ('910', '32'),
#  ('911', '11'),
#  ('912', '27'),
#  ('913', '15'),
#  ('914', '9'),
#  ('915', '25'),
#  ('916', '48'),
#  ('917', '18'),
#  ('918', '38'),
#  ('919', '20'),
#  ('920', '27'),
#  ('921', '23'),
#  ('922', '19'),
#  ('923', '21'),
#  ('924', '21'),
#  ('925', '18'),
#  ('926', '49'),
#  ('927', '9'),
#  ('928', '58'),
#  ('929', '24'),
#  ('930', '18'),
#  ('931', '17'),
#  ('932', '25'),
#  ('933', '87'),
#  ('934', '31'),
#  ('935', '14'),
#  ('936', '39'),
#  ('937', '16'),
#  ('938', '29'),
#  ('939', '10'),
#  ('940', '14'),
#  ('941', '14'),
#  ('942', '12'),
#  ('943', '34'),
#  ('944', '26'),
#  ('945', '53'),
#  ('946', '55'),
#  ('947', '41'),
#  ('948', '55'),
#  ('949', '29'),
#  ('950', '26'),
#  ('951', '12'),
#  ('952', '46'),
#  ('953', '32'),
#  ('954', '62'),
#  ('955', '52'),
#  ('956', '78'),
#  ('957', '37'),
#  ('958', '91'),
#  ('959', '119'),
#  ('960', '28'),
#  ('961', '30'),
#  ('962', '31'),
#  ('963', '66'),
#  ('964', '32'),
#  ('965', '26'),
#  ('966', '22'),
#  ('967', '20'),
#  ('968', '22'),
#  ('969', '37'),
#  ('970', '22'),
#  ('971', '73'),
#  ('972', '33'),
#  ('973', '52'),
#  ('974', '44'),
#  ('975', '9'),
#  ('976', '31'),
#  ('977', '17'),
#  ('978', '22'),
#  ('979', '20'),
#  ('980', '20'),
#  ('981', '22'),
#  ('982', '49'),
#  ('983', '8'),
#  ('984', '65'),
#  ('985', '22'),
#  ('986', '38'),
#  ('987', '29'),
#  ('988', '8'),
#  ('989', '44'),
#  ('990', '25'),
#  ('991', '24'),
#  ('992', '27'),
#  ('993', '28'),
#  ('994', '32'),
#  ('995', '93'),
#  ('996', '24'),
#  ('997', '21'),
#  ('998', '47'),
#  ('999', '30'),
#  ('1000', '12'),
#  ...]

# %% [markdown]
# ¿Cuantas filas hay en la base de datos?

# %%
conn = sqlite3.connect('db.db')
cur = conn.cursor()

cur.execute("SELECT COUNT(*) FROM t;")
row_count = cur.fetchone()[0]
print(f"El numero de filas en la base de datos es: {row_count}")


conn.close()
# Out:
# El numero de filas en la base de datos es: 10000

# %% [markdown]
# ¿Cual es el máximo `GameLength` y en qué `GameNumber` se realizó?

# %%
conn = sqlite3.connect('db.db')
cur = conn.cursor()

cur.execute("SELECT GameNumber, GameLength FROM t ORDER BY GameLength DESC LIMIT 1;")
max_game = cur.fetchone()
print(f"El maximo GameLength es {max_game[1]} y se realizo en el GameNumber {max_game[0]}.")


conn.close()
# Out:
# El maximo GameLength es 99 y se realizo en el GameNumber 363.

# %% [markdown]
# # API Requests
# Por lo general, conseguimos datos a traves de internet. Aunque el concepto de Application Programming Interface (API) es muy amplio y muy poco concreto, en el contexto de los servidores, es un conjunto de 'endpoints' que los servidores ofrecen para poder leer/procesar/escribir información en estos mismos.
#
# [En este repositorio](https://github.com/public-apis/public-apis) van a encontrar una lista de APIs públicas (pueden elegir otras que no son de ese repositorio). Para la consigna, se recomienda usar aquellas APIs que no requieren autenticación. Si se elige una API con autenticación, por favor, adjuntar las keys o pasarl las credenciales necesarias para su futura ejecución También, pueden usar varias URLs.

# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer una request GET e imprimir uno de los campos de la respuesta:

# %%
import requests

url = "https://api.adviceslip.com/advice"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print("Datos recibidos:")
    print(data)
else:
    print("Error al obtener los datos. Código de estado:", response.status_code)
# Out:
# Datos recibidos:
# {'slip': {'id': 146, 'advice': 'Today, do not use the words "Kind of", "Sort of" or "Maybe". It either is or it isn\'t.'}}

# %% [markdown]
# Hacer una request GET y, apartir de los campos en la respuesta, generar otro campo (por ejemplo, si la respuesta solo incluye un timestamp y una posición del registro, elaborar la velocidad del registro)

# %%
consejo = data["slip"]["advice"]

length_del_consejo = len(consejo)
print(f"Consejo: {consejo}")
print(f"Longitud del consejo: {length_del_consejo} caracteres")
# Out:
# Consejo: Today, do not use the words "Kind of", "Sort of" or "Maybe". It either is or it isn't.
# Longitud del consejo: 86 caracteres

# %% [markdown]
# # Streaming data
# Ahora vamos a hacer algo muy parecido a lo anterior, pero vamos a usar APIs que nos ofrecen datos en tiempo real. Pueden encontrar APIs de este estilo [en este repositorio](https://github.com/ColinEberhardt/awesome-public-streaming-datasets) (pueden elegir otras que no son de ese repositorio)

# %% [markdown]
# ## Consigna

# %% [markdown]
# Hacer un plot con `matplotlib` de una variable de una API de datos streaming en el que el eje 'y' sea la variable y el eje 'x' el tiempo.

# %%
#este precise bastante ayuda

import requests
import matplotlib.pyplot as plt
from datetime import datetime
import time

url = "https://api.coinbase.com/v2/prices/BTC-EUR/spot"

tiempos = []
precios = []

for _ in range(10):
    respuesta = requests.get(url)
    datos = respuesta.json()
    precio = float(datos["data"]["amount"])

    tiempos.append(datetime.now())
    precios.append(precio)

    print("Tiempos:", tiempos)
    print("Precios:", precios)

    if len(tiempos) > 10:
        tiempos = tiempos[-10:]
        precios = precios[-10:]

    plt.figure(figsize=(5, 3))
    plt.plot(tiempos, precios)
    plt.title("BTC/EUR en tiempo real")
    plt.xlabel("Tiempo")
    plt.ylabel("Precio (EUR)")
    plt.xticks(rotation=90)
    plt.grid(True)
    plt.pause(2)

print("terminado")
# Out:
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939)]
# Precios: [94928.49]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733)]
# Precios: [94928.49, 94929.045]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070)]
# Precios: [94928.49, 94929.045, 94909.055]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787), datetime.datetime(2024, 11, 22, 17, 0, 9, 632909)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055, 94909.055]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787), datetime.datetime(2024, 11, 22, 17, 0, 9, 632909), datetime.datetime(2024, 11, 22, 17, 0, 12, 158309)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055, 94909.055, 94929.045]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787), datetime.datetime(2024, 11, 22, 17, 0, 9, 632909), datetime.datetime(2024, 11, 22, 17, 0, 12, 158309), datetime.datetime(2024, 11, 22, 17, 0, 14, 642734)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055, 94909.055, 94929.045, 94923.755]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787), datetime.datetime(2024, 11, 22, 17, 0, 9, 632909), datetime.datetime(2024, 11, 22, 17, 0, 12, 158309), datetime.datetime(2024, 11, 22, 17, 0, 14, 642734), datetime.datetime(2024, 11, 22, 17, 0, 17, 108035)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055, 94909.055, 94929.045, 94923.755, 94909.055]
# Tiempos: [datetime.datetime(2024, 11, 22, 16, 59, 57, 219939), datetime.datetime(2024, 11, 22, 16, 59, 59, 826733), datetime.datetime(2024, 11, 22, 17, 0, 2, 248070), datetime.datetime(2024, 11, 22, 17, 0, 4, 648085), datetime.datetime(2024, 11, 22, 17, 0, 7, 132787), datetime.datetime(2024, 11, 22, 17, 0, 9, 632909), datetime.datetime(2024, 11, 22, 17, 0, 12, 158309), datetime.datetime(2024, 11, 22, 17, 0, 14, 642734), datetime.datetime(2024, 11, 22, 17, 0, 17, 108035), datetime.datetime(2024, 11, 22, 17, 0, 19, 548004)]
# Precios: [94928.49, 94929.045, 94909.055, 94922.28, 94909.055, 94909.055, 94929.045, 94923.755, 94909.055, 94923.755]
# ¡Listo!
